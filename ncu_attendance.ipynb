# %%
import re
import csv
import pandas as pd

#enter the path of input attendance file after removving the special symbols from column1 
x=pd.read_csv("/Users/sourabhsharma/Desktop/IEEE/meetingAttendanceList7.csv","rb")

print(x)

x=pd.DataFrame(x)
print(x)


y=x
l=[]
l_list=[]
for s in y:
    
    rr=re.findall("(\d\d[a-z]{3}\d\d\d)", s)
    l.append(rr)
    print(rr)

for bb in l:
    if bb not in l_list:
        l_list.append(bb)


l_list.sort()
#print(l_list)
        
#if y[]== 
#print(y)

df=pd.DataFrame()
df["attendees roll_no"]=l_list
#enter the path of the output file with name
df.to_excel('/Users/sourabhsharma/Desktop/IEEE/Results.xlsx', index = False) 


#if y[]=="ncu"
# Out:
#    ��Full Name\tUser Action\tTimestamp
# 0
# 1   srishti sharma\tJoined\t...
# 2
# 3   hitesh18csu086\tJoined\t...
# 4
# 5   anshika18csu047\tJoined...
# 6
# 7   dhruv18csu100\tJoined\t"...
# 8
# 9   bharat18csu044\tJoined\t...
# 10
# 11  anuj18csu028\tJoined\t"8...
# 12
# 13  ishwar18csu092\tJoined\t...
# 14
# 15  hemanshu18csu084\tJoine...
# 16
# 17  deeksha18csu057\tJoined...
# 18
# 19  chayan18csu054\tJoined\t...
# 20
# 21  bharat18csu043\tJoined\t...
# 22
# 23  ashish18csu038\tJoined\t...
# 24
# 25  aryan18csu037\tJoined\t"...
# 26
# 27  diwakar18csu065\tJoined...
# 28
# 29  harshit18csu080\tJoined...
# 30
# 31  devesh18csu061\tJoined\t...
# 32
# 33  jagrit18csu093\tJoined\t...
# 34
# 35  hrithik18csu088\tJoined...
# 36
# 37  deepanshu18csu059\tJoin...
# 38
# 39  deepanshu18csu059\tLeft...
# 40
# 41  deepanshu18csu059\tJoin...
# 42
# 43
#    ��Full Name\tUser Action\tTimestamp
# 0
# 1   srishti sharma\tJoined\t...
# 2
# 3   hitesh18csu086\tJoined\t...
# 4
# 5   anshika18csu047\tJoined...
# 6
# 7   dhruv18csu100\tJoined\t"...
# 8
# 9   bharat18csu044\tJoined\t...
# 10
# 11  anuj18csu028\tJoined\t"8...
# 12
# 13  ishwar18csu092\tJoined\t...
# 14
# 15  hemanshu18csu084\tJoine...
# 16
# 17  deeksha18csu057\tJoined...
# 18
# 19  chayan18csu054\tJoined\t...
# 20
# 21  bharat18csu043\tJoined\t...
# 22
# 23  ashish18csu038\tJoined\t...
# 24
# 25  aryan18csu037\tJoined\t"...
# 26
# 27  diwakar18csu065\tJoined...
# 28
# 29  harshit18csu080\tJoined...
# 30
# 31  devesh18csu061\tJoined\t...
# 32
# 33  jagrit18csu093\tJoined\t...
# 34
# 35  hrithik18csu088\tJoined...
# 36
# 37  deepanshu18csu059\tJoin...
# 38
# 39  deepanshu18csu059\tLeft...
# 40
# 41  deepanshu18csu059\tJoin...
# 42
# 43
# []
# /Users/sourabhsharma/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
x
# Out:
#    ��Full Name\tUser Action\tTimestamp
# 0
# 1   srishti sharma\tJoined\t...
# 2
# 3   hitesh18csu086\tJoined\t...
# 4
# 5   anshika18csu047\tJoined...
# 6
# 7   dhruv18csu100\tJoined\t"...
# 8
# 9   bharat18csu044\tJoined\t...
# 10
# 11  anuj18csu028\tJoined\t"8...
# 12
# 13  ishwar18csu092\tJoined\t...
# 14
# 15  hemanshu18csu084\tJoine...
# 16
# 17  deeksha18csu057\tJoined...
# 18
# 19  chayan18csu054\tJoined\t...
# 20
# 21  bharat18csu043\tJoined\t...
# 22
# 23  ashish18csu038\tJoined\t...
# 24
# 25  aryan18csu037\tJoined\t"...
# 26
# 27  diwakar18csu065\tJoined...
# 28
# 29  harshit18csu080\tJoined...
# 30
# 31  devesh18csu061\tJoined\t...
# 32
# 33  jagrit18csu093\tJoined\t...
# 34
# 35  hrithik18csu088\tJoined...
# 36
# 37  deepanshu18csu059\tJoin...
# 38
# 39  deepanshu18csu059\tLeft...
# 40
# 41  deepanshu18csu059\tJoin...
# 42
# 43

# %%
import re
import csv
import pandas as pd

#enter the path of input attendance file after removving the special symbols from column1 
x=pd.read_csv("/Users/sourabhsharma/Desktop/ncu/meetingAttendanceList7.csv",encoding = "utf-16",sep = "\t")



    


y=x["Full Name"]
l=[]
l_list=[]
for s in y:
    
    rr=re.findall("(\d\d[a-z]{3}\d\d\d)", s)
    l.append(rr)
    print(rr)

for bb in l:
    if bb not in l_list:
        l_list.append(bb)


l_list.sort()
#print(l_list)
        
#if y[]== 
#print(y)

df=pd.DataFrame()
df["attendees roll_no"]=l_list
#enter the path of the output file with name
df.to_excel('/Users/sourabhsharma/Desktop/ncu/Results.xlsx', index = False) 


#if y[]=="ncu"
# Out:
# []
# ['18csu086']
# ['18csu047']
# ['18csu100']
# ['18csu044']
# ['18csu028']
# ['18csu092']
# ['18csu084']
# ['18csu057']
# ['18csu054']
# ['18csu043']
# ['18csu038']
# ['18csu037']
# ['18csu065']
# ['18csu080']
# ['18csu061']
# ['18csu093']
# ['18csu088']
# ['18csu059']
# ['18csu059']
# ['18csu059']
